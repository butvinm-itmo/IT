# %%
import pandas as pd

# %%
data = pd.read_csv('./data.csv')
data['<DATE>'] = pd.to_datetime(data['<DATE>'], format='%d/%m/%Y')
data
# Out:
#              <TICKER>  <PER>     <DATE> <TIME>  <OPEN>  <HIGH>   <LOW>  \
# 0      SPFB.RTS-12.18      1 2018-09-03  10:01  107900  108060  107900
# 1      SPFB.RTS-12.18      1 2018-09-03  10:02  107960  107960  107960
# 2      SPFB.RTS-12.18      1 2018-09-03  10:04  108000  108000  108000
# 3      SPFB.RTS-12.18      1 2018-09-03  10:05  108000  108000  108000
# 4      SPFB.RTS-12.18      1 2018-09-03  10:08  108080  108080  108080
# ...               ...    ...        ...    ...     ...     ...     ...
# 58965  SPFB.RTS-12.18      1 2018-12-20  18:40  109380  109380  109380
# 58966  SPFB.RTS-12.18      1 2018-12-20  18:41  109380  109390  109380
# 58967  SPFB.RTS-12.18      1 2018-12-20  18:43  109380  109390  109380
# 58968  SPFB.RTS-12.18      1 2018-12-20  18:44  109390  109390  109390
# 58969  SPFB.RTS-12.18      1 2018-12-20  18:45  109390  109390  109380
#
#        <CLOSE>  <VOL>
# 0       108030      3
# 1       107960      5
# 2       108000      8
# ...

# %%
sep_data = data[data['<DATE>'].between('2018-09-05', '2018-09-05')][['<OPEN>', '<HIGH>', '<LOW>', '<CLOSE>']]
sep_data.Name = '2018-09-05'

oct_data = data[data['<DATE>'].between('2018-10-05', '2018-10-05')][['<OPEN>', '<HIGH>', '<LOW>', '<CLOSE>']]
oct_data.Name = '2018-10-05'

nov_data = data[data['<DATE>'].between('2018-11-07', '2018-11-07')][['<OPEN>', '<HIGH>', '<LOW>', '<CLOSE>']]
nov_data.Name = '2018-11-07'

dec_data = data[data['<DATE>'].between('2018-12-05', '2018-12-05')][['<OPEN>', '<HIGH>', '<LOW>', '<CLOSE>']]
dec_data.Name = '2018-12-05'
dec_data
# Out:
#        <OPEN>  <HIGH>   <LOW>  <CLOSE>
# 49570  113460  113540  113030   113180
# 49571  113200  113340  113190   113240
# 49572  113250  113450  113240   113370
# 49573  113380  113490  113360   113440
# 49574  113430  113640  113430   113550
# ...       ...     ...     ...      ...
# 50375  114980  114980  114920   114940
# 50376  114940  114950  114930   114950
# 50377  114930  114950  114920   114930
# 50378  114920  114980  114880   114980
# 50379  114970  115050  114960   115050
#
# [810 rows x 4 columns]

# %%
# rename cols
for df in (sep_data, oct_data, nov_data, dec_data):
    df.rename(columns={
        col: f'{df.Name} {col}' for col in df.columns
    }, inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
sep_data
# Out:
#      2018-09-05 <OPEN>  2018-09-05 <HIGH>  2018-09-05 <LOW>  \
# 378             106550             106550            106040
# 379             106270             106270            106170
# 380             106300             106300            106250
# 381             106250             106250            106250
# 382             106160             106160            106110
# ..                 ...                ...               ...
# 603             106340             106340            106340
# 604             106390             106390            106360
# 605             106250             106250            106250
# 606             106280             106280            106280
# 607             106300             106300            106300
#
#      2018-09-05 <CLOSE>
# 378              106270
# 379              106210
# 380              106250
# 381              106250
# 382              106110
# ..                  ...
# 603              106340
# 604              106360
# ...

# %%
figures = [
    (plt.figure(figsize=(20, 10)), df.boxplot())
    for df in (sep_data, oct_data, nov_data, dec_data)
]
